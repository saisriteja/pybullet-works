# %%
import pybullet as p
import time
import pybullet_data
from numpngw import write_apng
from IPython.display import Image
import numpy as np




p.connect(p.GUI)
p.setAdditionalSearchPath(pybullet_data.getDataPath())

#making a collision shape
p.createCollisionShape(p.GEOM_PLANE)
p.createMultiBody(0, 0)


sphereRadius = 0.05

#make a sphere and box of a particular radius
colSphereId = p.createCollisionShape(p.GEOM_SPHERE, radius=sphereRadius)
colBoxId = p.createCollisionShape(p.GEOM_BOX,
                                  halfExtents=[sphereRadius, sphereRadius, sphereRadius])


#mass
mass = 1


visualShapeId = -1
link_Masses = [1]
linkCollisionShapeIndices = [colBoxId]
linkVisualShapeIndices = [-1]

#position and orientation
linkPositions = [[0, 0, 0.11]]
linkOrientations = [[0, 0, 0, 1]]


linkInertialFramePositions = [[0, 0, 0]]
linkInertialFrameOrientations = [[0, 0, 0, 1]]

indices = [0]

#joint types to move
jointTypes = [p.JOINT_REVOLUTE]

#translation or rotatinal axis
axis = [[0, 0, 1]]


for i in range(3):
  for j in range(3):
    for k in range(3):
        
        
      #position and orientation to keep the box  
      basePosition = [
          1 + i * 5 * sphereRadius, 1 + j * 5 * sphereRadius, 1 + k * 5 * sphereRadius + 1
      ]
    
    
      baseOrientation = [0, 0, 0, 1]
        
        
      
      # at top layer add a few spheres
      if (k & 2):
        sphereUid = p.createMultiBody(mass, colSphereId, visualShapeId, basePosition,
                                      baseOrientation)
        
      # for lower layers add a few boxes
      else:
        sphereUid = p.createMultiBody(mass,
                                      colBoxId,
                                      visualShapeId,
                                      basePosition,
                                      baseOrientation,
                                      linkMasses=link_Masses,
                                      linkCollisionShapeIndices=linkCollisionShapeIndices,
                                      linkVisualShapeIndices=linkVisualShapeIndices,
                                      linkPositions=linkPositions,
                                      linkOrientations=linkOrientations,
                                      linkInertialFramePositions=linkInertialFramePositions,
                                      linkInertialFrameOrientations=linkInertialFrameOrientations,
                                      linkParentIndices=indices,
                                      linkJointTypes=jointTypes,
                                      linkJointAxis=axis)
        
      
      #change in physical properties of a object

      p.changeDynamics(sphereUid,
                       -1,
                       spinningFriction=0.001,
                       rollingFriction=0.001,
                       linearDamping=0.0)
    
    #set some predefined values to a object
      for joint in range(p.getNumJoints(sphereUid)):
        p.setJointMotorControl2(sphereUid, joint, p.VELOCITY_CONTROL, targetVelocity=1, force=10)
        
        
#set gravity in negative z direction
p.setGravity(0, 0, -10)
p.setRealTimeSimulation(1)


p.getNumJoints(sphereUid)
for i in range(p.getNumJoints(sphereUid)):
  print(p.getJointInfo(sphereUid, i))

width = 800
height = 500

frames = []

for i in range(100):
  keys = p.getKeyboardEvents()
#   print(keys)
    
#   img_arr=p.getCameraImage(width, height, renderer=p.ER_BULLET_HARDWARE_OPENGL)
#   w = img_arr[0]  #width of the image, in pixels
#   h = img_arr[1]  #height of the image, in pixels
#   rgb = img_arr[2]  #color data RGB
#   dep = img_arr[3]  #depth data
#   np_img_arr = np.reshape(rgb, (h, w, 4))
#   frame = np_img_arr[:, :, :3]
#   frames.append(frame)

  time.sleep(0.01)

# %time write_apng("simulation.png", frames, delay=100)
# %time Image(filename="simulation.png")
# Out:
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}

# %%
import pybullet as p
import time
import pybullet_data
from numpngw import write_apng
from IPython.display import Image
import numpy as np




p.connect(p.GUI)
p.setAdditionalSearchPath(pybullet_data.getDataPath())

#making a collision shape
p.createCollisionShape(p.GEOM_PLANE)
p.createMultiBody(0, 0)


sphereRadius = 0.05

#make a sphere and box of a particular radius
colSphereId = p.createCollisionShape(p.GEOM_SPHERE, radius=sphereRadius)
colBoxId = p.createCollisionShape(p.GEOM_BOX,
                                  halfExtents=[sphereRadius, sphereRadius, sphereRadius])


#mass
mass = 1


visualShapeId = -1
link_Masses = [1]
linkCollisionShapeIndices = [colBoxId]
linkVisualShapeIndices = [-1]

#position and orientation
linkPositions = [[0, 0, 0.11]]
linkOrientations = [[0, 0, 0, 1]]


linkInertialFramePositions = [[0, 0, 0]]
linkInertialFrameOrientations = [[0, 0, 0, 1]]

indices = [0]

#joint types to move
jointTypes = [p.JOINT_SPHERICAL]

#translation or rotatinal axis
axis = [[0, 0, 1]]


for i in range(3):
  for j in range(3):
    for k in range(3):
        
        
      #position and orientation to keep the box  
      basePosition = [
          1 + i * 5 * sphereRadius, 1 + j * 5 * sphereRadius, 1 + k * 5 * sphereRadius + 1
      ]
    
    
      baseOrientation = [0, 0, 0, 1]
        
        
      
      # at top layer add a few spheres
      if (k & 2):
        sphereUid = p.createMultiBody(mass, colSphereId, visualShapeId, basePosition,
                                      baseOrientation)
        
      # for lower layers add a few boxes
      else:
        sphereUid = p.createMultiBody(mass,
                                      colBoxId,
                                      visualShapeId,
                                      basePosition,
                                      baseOrientation,
                                      linkMasses=link_Masses,
                                      linkCollisionShapeIndices=linkCollisionShapeIndices,
                                      linkVisualShapeIndices=linkVisualShapeIndices,
                                      linkPositions=linkPositions,
                                      linkOrientations=linkOrientations,
                                      linkInertialFramePositions=linkInertialFramePositions,
                                      linkInertialFrameOrientations=linkInertialFrameOrientations,
                                      linkParentIndices=indices,
                                      linkJointTypes=jointTypes,
                                      linkJointAxis=axis)
        
      
      #change in physical properties of a object

      p.changeDynamics(sphereUid,
                       -1,
                       spinningFriction=0.001,
                       rollingFriction=0.001,
                       linearDamping=0.0)
    
    #set some predefined values to a object
      for joint in range(p.getNumJoints(sphereUid)):
        p.setJointMotorControl2(sphereUid, joint, p.VELOCITY_CONTROL, targetVelocity=1, force=10)
        
        
#set gravity in negative z direction
p.setGravity(0, 0, -10)
p.setRealTimeSimulation(1)


p.getNumJoints(sphereUid)
for i in range(p.getNumJoints(sphereUid)):
  print(p.getJointInfo(sphereUid, i))

width = 800
height = 500

frames = []

for i in range(100):
  keys = p.getKeyboardEvents()


  time.sleep(0.01)
# Out:
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
